# %%
#Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import scipy.stats as sts
import gmaps
import gmaps.geojson_geometries
import time
from pprint import pprint

#Import API Keys
from config import (gkey, ckey)

# %%
covid_data=pd.read_csv("Resources/us-counties.csv")
covid_data=covid_data.loc[covid_data["date"]== "2020-07-29"]
covid_data.reset_index(drop=True, inplace=True)

# %%
covid_data["Lat"]=""
covid_data["Lng"]=""
covid_data
# Out:
#             date      county    state     fips  cases  deaths Lat Lng
# 0     2020-07-29     Autauga  Alabama   1001.0    987      21
# 1     2020-07-29     Baldwin  Alabama   1003.0   2908      21
# 2     2020-07-29     Barbour  Alabama   1005.0    584       4
# 3     2020-07-29        Bibb  Alabama   1007.0    344       2
# 4     2020-07-29      Blount  Alabama   1009.0    694       3
# ...          ...         ...      ...      ...    ...     ...  ..  ..
# 3212  2020-07-29  Sweetwater  Wyoming  56037.0    234       2
# 3213  2020-07-29       Teton  Wyoming  56039.0    318       1
# 3214  2020-07-29       Uinta  Wyoming  56041.0    245       1
# 3215  2020-07-29    Washakie  Wyoming  56043.0     44       5
# 3216  2020-07-29      Weston  Wyoming  56045.0      5       0
#
# [3217 rows x 8 columns]

# %%
params={"key":gkey}
for index,row in covid_data.iterrows():
    base_url="https://maps.googleapis.com/maps/api/geocode/json"
    county=row["county"]
    state=row["state"]
    params["address"]=f"{county},{state}"
    result=requests.get(base_url, params=params)
    result=result.json()
    try:    
        covid_data.loc[index, "Lat"] = result["results"][0]["geometry"]["location"]["lat"]
        covid_data.loc[index, "Lng"] = result["results"][0]["geometry"]["location"]["lng"]
        time.sleep(1)
    except (IndexError, KeyError):
        print("results not found...skipping")
        time.sleep(1)
print("-"*30)
print("Complete")
# Out:
# results not found...skipping
# ------------------------------
# Complete

# %%
covid_data
# Out:
#             date      county    state     fips  cases  deaths      Lat  \
# 0     2020-07-29     Autauga  Alabama   1001.0    987      21  32.5792
# 1     2020-07-29     Baldwin  Alabama   1003.0   2908      21  30.6011
# 2     2020-07-29     Barbour  Alabama   1005.0    584       4  31.8173
# 3     2020-07-29        Bibb  Alabama   1007.0    344       2  32.9563
# 4     2020-07-29      Blount  Alabama   1009.0    694       3  34.0145
# ...          ...         ...      ...      ...    ...     ...      ...
# 3212  2020-07-29  Sweetwater  Wyoming  56037.0    234       2  41.8519
# 3213  2020-07-29       Teton  Wyoming  56039.0    318       1  43.8536
# 3214  2020-07-29       Uinta  Wyoming  56041.0    245       1  41.2107
# 3215  2020-07-29    Washakie  Wyoming  56043.0     44       5  43.0063
# 3216  2020-07-29      Weston  Wyoming  56045.0      5       0  44.6369
#
#           Lng
# 0    -86.4997
# 1    -87.7763
# 2     -85.355
# 3    -87.1423
# 4    -86.4997
# ...       ...
# 3212 -109.188
# 3213 -110.631
# 3214 -110.617
# 3215 -108.882
# 3216 -105.336
#
# [3217 rows x 8 columns]

# %%
gmaps.configure(api_key=gkey)
locations=covid_data["county"]
case_count=covid_data["cases"]

# %%
fig=gmaps.figure()
county_geojson=gmaps.geojson_geometries.load_geometry("counties")
county_lines=gmaps.geojson_layer(county_geojson)
fig.add_layer(county_lines)
fig
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-036ae0972e2d> in <module>
#       1 fig=gmaps.figure()
# ----> 2 county_geojson=gmaps.geojson_geometries.load_geometry("counties")
#       3 county_lines=gmaps.geojson_layer(county_geojson)
#       4 fig.add_layer(county_lines)
#       5 fig
#
# ~\anaconda3\lib\site-packages\gmaps\geojson_geometries\geojson_geometries.py in load_geometry(geometry_name)
#     103     >>> fig
#     104     """
# --> 105     url = METADATA[geometry_name]["url"]
#     106     reader = codecs.getreader("utf-8")
#     107     f = urlopen(url)
#
# KeyError: 'counties'
